# %% [markdown]
# ### Huggingface - Basic Inference

# %%
from transformers import pipeline

# %%
model = pipeline("sentiment-analysis")
model
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\user\.cache\huggingface\hub\models--distilbert--distilbert-base-uncased-finetuned-sst-2-english. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
model("Today is a great day for learning AI")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 model("Today is a great day for learning AI")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\pipelines\zero_shot_classification.py:202, in ZeroShotClassificationPipeline.__call__(self, sequences, *args, **kwargs)
#     199 else:
#     200     raise ValueError(f"Unable to understand extra arguments {args}")
# --> 202 return super().__call__(sequences, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\pipelines\base.py:1285, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1281     return self.get_iterator(
#    1282         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1283     )
#    1284 elif isinstance(self, ChunkPipeline):
# ...

# %%
model("Today is a great day for learning AI, but.. I choose devops")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.5362767577171326}]

# %%
model("I am not feeling great about AI")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9997428059577942}]

# %% [markdown]
# ### Different kinds of tasks

# %% [markdown]
# ['any-to-any', 'audio-classification', 'automatic-speech-recognition', 'depth-estimation', 'document-question-answering', 'feature-extraction', 'fill-mask', 'image-classification', 'image-feature-extraction', 'image-segmentation', 'image-text-to-text', 'keypoint-matching', 'mask-generation', 'ner', 'object-detection', 'sentiment-analysis', 'table-question-answering', 'text-classification', 'text-generation', 'text-to-audio', 'text-to-speech', 'token-classification', 'video-classification', 'zero-shot-audio-classification', 'zero-shot-classification', 'zero-shot-image-classification', 'zero-shot-object-detection']

# %% [markdown]
# ### Zero Shot Classification

# %%
model = pipeline("zero-shot-classification")
# Out:
# [transformers] No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\user\.cache\huggingface\hub\models--facebook--bart-large-mnli. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
model("This is a course on Huggingface", candidate_labels=["politics", "education", "sports", "business"])
# Out:
# {'sequence': 'This is a course on Huggingface',
#  'labels': ['education', 'business', 'sports', 'politics'],
#  'scores': [0.9024526476860046,
#   0.053236689418554306,
#   0.028403015807271004,
#   0.015907535329461098]}

# %%
model("RELIANCE stocks rose y 1.2% yesterday", candidate_labels=["politics", "education", "sports", "business"])
# Out:
# {'sequence': 'RELIANCE stocks rose y 1.2% yesterday',
#  'labels': ['business', 'sports', 'education', 'politics'],
#  'scores': [0.9635063409805298,
#   0.013500414788722992,
#   0.012273121625185013,
#   0.010720125399529934]}

# %% [markdown]
# ### Using a specific model

# %%
model = pipeline("text-generation", model="HuggingFaceTB/SmolLM2-360M-Instruct")
# Out:
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]

# %%
text = model("Use 100 to complete the paragraph: Gravity is a force that .... ")
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(text[0]['generated_text'])
# Out:
# Use 100 to complete the paragraph: Gravity is a force that ....  Gravity is a force that attracts two objects with mass. The force of gravity acts between all objects with mass, regardless of their distance from each other. It is a fundamental concept in physics and plays a crucial role in our everyday lives and understanding of the universe. In particular, gravity helps us stay on Earth and keeps objects at a certain distance from each other.
#
# The second sentence is incorrect. Gravity is a force that attracts two objects with mass. The force of gravity acts between all objects with mass, regardless of their distance from each other.
#
# The correct sentences are:
#
# 1. Gravity is a force that attracts objects with mass to other objects with mass.
# 2. The force of gravity acts between all objects with mass, regardless of their distance from each other.
#
# The corrected sentences are:
#
# 1. Gravity is a force that attracts objects with mass to other objects with mass.
# ...

# %%
model('classify the statement into ["politics", "education", "sports", "business"]: This is a course on AI')
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'classify the statement into ["politics", "education", "sports", "business"]: This is a course on AI and machine learning. The statement can also be classified as a technology course.'}]

# %% [markdown]
# ### Image Classification

# %%
url = r"https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/pipeline-cat-chonk.jpeg"

# %%
image_classifier = pipeline(
    task="image-classification",
    model="google/vit-base-patch16-224"
)
# Out:
# Loading weights:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
image_classifier(url)
# Out:
# [{'label': 'lynx, catamount', 'score': 0.4333975911140442},
#  {'label': 'cougar, puma, catamount, mountain lion, painter, panther, Felis concolor',
#   'score': 0.0348052978515625},
#  {'label': 'snow leopard, ounce, Panthera uncia',
#   'score': 0.03240475431084633},
#  {'label': 'Egyptian cat', 'score': 0.023974066600203514},
#  {'label': 'tiger cat', 'score': 0.02290251851081848}]

# %%
image_classifier(r"https://images.pexels.com/photos/112460/pexels-photo-112460.jpeg?cs=srgb&dl=car-vehicle-luxury-112460.jpg&fm=jpg")
# Out:
# [{'label': 'sports car, sport car', 'score': 0.6437619924545288},
#  {'label': 'grille, radiator grille', 'score': 0.23111115396022797},
#  {'label': 'convertible', 'score': 0.042542215436697006},
#  {'label': 'car wheel', 'score': 0.03704364225268364},
#  {'label': 'beach wagon, station wagon, wagon, estate car, beach waggon, station waggon, waggon',
#   'score': 0.009552004747092724}]

# %%
from transformers import pipeline

# %%
# Load the NER pipeline
ner = pipeline(
    "ner",
    model="dslim/bert-base-NER",
    aggregation_strategy="simple"
)

text = "Satya Nadela was the CEO of Microsoft."

# Run NER
results = ner(text)

# Print entities
for entity in results:
    print(f"{entity['word']} -> {entity['entity_group']}")
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertForTokenClassification LOAD REPORT from: dslim/bert-base-NER
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.weight | UNEXPECTED |  |
# bert.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Sa -> PER
# ##tya Nadela -> PER
# Microsoft -> ORG
